# %%
# main.ipynb

import sys
import os

# Verify and print current directory (for debugging)
print("Current Working Directory:", os.getcwd())

# Define the path to the 'Modules' directory
modules_path = os.path.join(os.getcwd(), 'Modules')
sys.path.append(modules_path)

# Import the merging module
import merging_and_cleaning as mc

# Execute the function to perform data merging and cleaning
print("Merging and Cleaning Data...")
mc.merge_and_clean()

# Import hypothesis modules to execute their visualizations
import h1_price_changes as h1
import h2_volume_correlation as h2
import h3_market_dominance as h3
import h4_volatility as h4
# Out:
# Current Working Directory: c:\Users\Marc Jay\Ironhack\Project_Week_4_Cryptos
# Merging and Cleaning Data...
# Data Preparation Complete. Cleaned data saved as 'merged_df.csv' in the root directory.
